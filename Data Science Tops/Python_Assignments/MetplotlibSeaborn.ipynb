# %% [markdown]
# # Matplotlib

# %% [markdown]
# # Tips Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\mitps\\Downloads\\tips (1) (1).csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
import matplotlib.pyplot as plt
import numpy as np
avg_total_bill = df.groupby('day')['total_bill'].mean() 
plt.figure(figsize=(10,6))
avg_total_bill.plot.bar()
plt.title('Average Total Bill by Day')
plt.xlabel('Day')
plt.ylabel('Average Total Bill')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
avg_total_bill = df.groupby('day')['total_bill'].mean() 
plt.figure(figsize=(10,6))
avg_total_bill.plot.barh()
plt.title('Average Total Bill by Day')
plt.xlabel('Day')
plt.ylabel('Average Total Bill')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['time'], df['total_bill'])
plt.title('Total Bill Over Time')
plt.xlabel('Time')
plt.ylabel('Total Bill')
plt.show()

# %%
plt.figure(figsize=(8,8))
smoker_counts = df['smoker'].value_counts() 
print(smoker_counts)
explode = [0.2,0]
plt.pie(smoker_counts, labels=smoker_counts.index, explode=explode, autopct='%1.1f%%')
plt.show()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.hist(df['total_bill'],bins=20)
plt.title('Distribution of Total Bills')
plt.xlabel('total bill')

plt.show()

# %%
avg_total_bill = df.groupby('day')['total_bill'].mean()
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
avg_total_bill.plot.bar(ax=axes[0], color='k', alpha=0.9)
axes[0].set_title('Average Total Bill per Day (Vertical)')
axes[0].set_ylabel('Average Total Bill')
axes[0].set_xlabel('Day')
avg_total_bill.plot.barh(ax=axes[1], color='k', alpha=0.9)
axes[1].set_title('Average Total Bill per Day (Horizontal)')
axes[1].set_xlabel('Average Total Bill')
axes[1].set_ylabel('Day')
plt.show()

# %%
x = df['tip']
y = df['total_bill']
plt.scatter(x,y)

# %% [markdown]
# # Seaborn
# ### Tips Dataset

# %%
import seaborn as sns 
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[['total_bill', 'tip', 'size']].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
x = ['total_bill']
y = ['tip']
sns.scatterplot(tips, x = 'tip', y = 'total_bill', hue='time')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
# df = pd.DataFrame(tips)
plt.figure(figsize=(12, 6))

sns.histplot(data=tips, x='total_bill', bins=10)
plt.title('Total Bill Distribution')

plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(data=tips, x='tip',y='sex')
plt.title('Smoker Distribution')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Text(0.5, 1.0, 'Smoker Distribution')

# %%
sns.countplot(data=df, x='smoker')
plt.title('Smoker Distribution')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Text(0.5, 1.0, 'Smoker Distribution')

# %%
sns.lineplot(data=tips,x=tips.index,y='total_bill')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='total_bill'>

# %%
xyz = tips[['total_bill', 'tip', 'size']].corr() 
plt.figure(figsize=(8,6))
sns.heatmap(xyz, linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# # Matplotlib

# %% [markdown]
# # Titanic Dataset

# %%
df = pd.read_csv("C:\\Users\\mitps\\Downloads\\tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
survived_count = df['Survived'].value_counts()
plt.figure(figsize=(10,6))
plt.bar(survived_count.index, survived_count.values, color=['red','green'])
plt.xlabel('Survived')
plt.ylabel('No of Passengers')
plt.title('No of Passengers Survived Vs Not Survived')



# Display the plot
plt.show()

# %%
titanic_data = df.dropna(subset=['Age'])
drop_null = df.dropna(subset=['Age'])
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins = 20)
# plt.hist(titanic_data['Age'], bins=20, color='blue', edgecolor='black')
plt.xlabel('Age') 
# plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.title('Distribution of Passengers\' Ages')
plt.show()

# %%
survived_counts = df['Survived'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(survived_counts, labels=['Not Survived', 'Survived'], autopct='%1.1f%%',colors=['red', 'green'])
plt.title('Proportion of Passengers Who Survived vs. Not Survived')
plt.show()

# %%
titanic_data = df.dropna(subset=['Age', 'Fare'])
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Fare'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs. Fare')
plt.grid(True)
plt.show()

# %%
gender_counts = df['Sex'].value_counts()
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
ax[0].bar(gender_counts.index, gender_counts.values, color = 'k')
ax[0].set_xlabel('Gender')
ax[0].set_ylabel('Number of Passengers')
ax[0].set_title('Number of Passengers by Gender')
ax[1].barh(gender_counts.index, gender_counts.values, color = 'k')
ax[1].set_ylabel('Gender')
ax[1].set_xlabel('Number of Passengers')
ax[1].set_title('Number of Passengers by Gender')
plt.show()

# %% [markdown]
# # Seaborn
# ### Titanic Dataset

# %%
titanic = pd.read_csv("C:\\Users\\mitps\\Downloads\\tested.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
d = titanic.isnull().sum()
d
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic.drop(columns=['Cabin'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
age_data = titanic['Age']
plt.figure(figsize=(8, 6))
sns.histplot(data=age_data, kde=True, edgecolor='black')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.barplot(data=titanic, x='Fare',y='Sex')
# Out:
# <Axes: xlabel='Fare', ylabel='Sex'>

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=titanic, x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=titanic, x='Age', y='Fare', hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(data=titanic, x='PassengerId', y='Age', color='pink')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='PassengerId', ylabel='Age'>

# %%
xyz = titanic[['Survived', 'Fare']].corr() 
plt.figure(figsize=(8,6))
sns.heatmap(xyz, linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# # Liver_disease_data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\mitps\\Downloads\\Liver_disease_data.csv")
df.head()
# Out:
#    Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 0   58       0  35.857584           17.272828        0            1
# 1   71       1  30.732470            2.201266        0            1
# 2   48       0  19.971407           18.500944        0            0
# 3   34       1  16.615417           12.632870        0            0
# 4   62       1  16.065830            1.087815        0            1
#
#    PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# 0          0.658940         0             0          42.734240          1
# 1          1.670557         1             0          67.309822          1
# 2          9.928308         0             0          63.738956          0
# 3          5.630129         0             0          64.555873          1
# 4          3.566218         1             0          77.868689          1

# %%
null_value = df.isnull().sum()
null_value
# Out:
# Age                   0
# Gender                0
# BMI                   0
# AlcoholConsumption    0
# Smoking               0
# GeneticRisk           0
# PhysicalActivity      0
# Diabetes              0
# Hypertension          0
# LiverFunctionTest     0
# Diagnosis             0
# dtype: int64

# %%
df.tail()
# Out:
#       Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 1695   42       0  38.498295           14.384688        0            1
# 1696   40       0  27.600094            5.431009        0            0
# 1697   38       0  38.730017            6.324302        1            2
# 1698   67       0  35.820798           16.899417        0            2
# 1699   80       0  24.060783            9.526447        0            0
#
#       PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# 1695          0.992289         0             0          97.933961          1
# 1696          8.390492         0             0          70.260528          1
# 1697          9.314222         0             1          56.053370          1
# 1698          3.224453         0             0          26.300875          1
# 1699          9.261426         0             1          73.572893          1

# %%
avg_total_alcohol_consumption = df.groupby('Gender')['AlcoholConsumption'].mean()
plt.figure(figsize=(10,6))
avg_total_alcohol_consumption.plot.bar() 
plt.title("avg_total_alcohol_consumption")
plt.xlabel('Gender')

plt.ylabel('AlcoholConsumption')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['LiverFunctionTest'], bins = 20, edgecolor = 'black')
# plt.hist(titanic_data['Age'], bins=20, color='blue', edgecolor='black')
plt.xlabel('LiverFunctionTest') 
# plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Liver Function Test Values')
# plt.grid(True)
plt.show()

# %%
# Pie chart of Diagnosis distribution
# diagnosis_counts = data['Diagnosis'].value_counts()
diagnosis_counts = df['Diagnosis'].value_counts() 
plt.figure(figsize=(8, 8))
explode = [0.2,0]
plt.pie(diagnosis_counts, labels = diagnosis_counts.index, autopct='%1.1f%%', startangle=140, explode = explode)
# plt.pie(diagnosis_counts, labels=diagnosis_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue'])
plt.title('Pie Chart of Diagnosis Distribution')
plt.axis('equal')
plt.show()

# %%
df.head()
liver = df.groupby('Diagnosis')['LiverFunctionTest'].mean() 
plt.figure(figsize=(10,6))
liver.plot.barh() 
plt.title('Avg Liver Function Test By Diagnosis')
plt.xlabel('LiverFunctionTest')
plt.show()

# %%
# Calculate gender counts
gender_counts = df['Gender'].value_counts()

# Create subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 6))

# Bar plot
ax[0].bar(gender_counts.index, gender_counts.values, color='k')
ax[0].set_xlabel('Gender')
ax[0].set_ylabel('Number of Records')
ax[0].set_title('Number of Records by Gender')

# Horizontal bar plot
ax[1].barh(gender_counts.index, gender_counts.values, color='k')
ax[1].set_ylabel('Gender')
ax[1].set_xlabel('Number of Records')
ax[1].set_title('Number of Records by Gender')

# Show plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Seaborn
# ### Liver_disease_data

# %%
liver = pd.read_csv("C:\\Users\\mitps\\Downloads\\Liver_disease_data.csv")
liver.head()
# Out:
#    Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 0   58       0  35.857584           17.272828        0            1
# 1   71       1  30.732470            2.201266        0            1
# 2   48       0  19.971407           18.500944        0            0
# 3   34       1  16.615417           12.632870        0            0
# 4   62       1  16.065830            1.087815        0            1
#
#    PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# 0          0.658940         0             0          42.734240          1
# 1          1.670557         1             0          67.309822          1
# 2          9.928308         0             0          63.738956          0
# 3          5.630129         0             0          64.555873          1
# 4          3.566218         1             0          77.868689          1

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=liver, x='LiverFunctionTest', bins=10, kde=True, color='skyblue')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='LiverFunctionTest', ylabel='Count'>

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=liver, x='Diagnosis')
# Out:
# <Axes: xlabel='Diagnosis', ylabel='count'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=liver, x='Age', y='BMI', hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
yzx = liver[['Diagnosis', 'LiverFunctionTest']].corr() 
plt.figure(figsize=(8,6))
sns.heatmap(yzx, annot=True,linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# # Online Sales Data

# %%
df = pd.read_csv("C:\\Users\\mitps\\Downloads\\Online Sales Data.csv")
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
Unit_Price_by_product_name = df.groupby('Product Name')['Unit Price'].mean() 
top_6_products = Unit_Price_by_product_name.nlargest(5)
plt.figure(figsize=(10,6))
top_6_products.plot.bar() 
plt.xticks(rotation=45)
plt.ylabel('Unit Price')
# Out:
# Text(0, 0.5, 'Unit Price')

# %%
df.groupby('Product Category')['Units Sold'].sum()
unit_sold_by_product_category.plot.barh()
plt.xlabel('Units Sold')
# Out:
# Text(0.5, 0, 'Units Sold')

# %%
daily_revenue = df.groupby('Date')['Total Revenue'].sum()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(daily_revenue.index, daily_revenue.values,  linestyle='-', color='b')
plt.title('Total Revenue Over Time')
plt.xlabel('Date')
plt.ylabel('Total Revenue')
plt.grid(True)
plt.xticks(rotation=0)

plt.show()

# %%
product_category_counts = df['Product Category'].value_counts()

# Plotting
plt.figure(figsize=(8, 8))
plt.pie(product_category_counts, labels=product_category_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Product Categories')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df['Total Revenue'],bins=20)
plt.title('Distribution of Total Revenue')
plt.xlabel('Total Revenue')

plt.show()

# %%
x = df['Product Category']
plt.xticks(rotation=45)
y = df['Total Revenue']
plt.scatter(x,y)
